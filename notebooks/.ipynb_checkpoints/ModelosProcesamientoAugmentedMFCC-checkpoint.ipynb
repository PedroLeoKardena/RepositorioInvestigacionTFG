# %% [markdown]
# # Entrenamiento de Modelos — MFCC con Datos Aumentados
#
# En este notebook seguimos la misma estructura que en `ModelosPreprocesamientoChunkedMFCC`, pero trabajando sobre el **dataset aumentado**. El data augmentation es una técnica habitual en machine learning que consiste en generar nuevas muestras de entrenamiento aplicando transformaciones a las muestras originales, con el objetivo de aumentar la variedad del conjunto de entrenamiento sin necesidad de recopilar nuevos datos.
#
# En nuestro caso, se aplicaron tres técnicas de augmentation sobre cada chunk de entrenamiento:
#
# 1. **Ruido gaussiano** — simula variaciones del entorno clínico (ruido de equipos, interferencias de sala).
# 2. **Pitch shift (+2 semitonos)** — simula variaciones en la fisiología vocal del paciente.
# 3. **Time stretch (×1.15)** — simula taquipnea leve (respiración un 15% más rápida).
#
# Como resultado, el conjunto de entrenamiento pasa de **1074 a 4296 muestras** (×4), mientras que el conjunto de test se mantiene en **247 muestras originales**, ya que el test nunca se aumenta: debe representar condiciones reales de inferencia.
#
# Esta expansión mejora notablemente la relación muestras/características, reduciendo el riesgo de sobreajuste:
#
# | Representación | Nº características | Ratio (aumentado) | Ratio (original) |
# |---|---|---|---|
# | Flat + PCA (≈171) | ~171 | 4296/171 ≈ **25:1** | 1074/171 ≈ 6:1 |
# | Flat + SelectKBest (75) | 75 | 4296/75 ≈ **57:1** | 1074/75 ≈ 14:1 |
# | Pool (≈60) | ~60 | 4296/60 ≈ **72:1** | 1074/60 ≈ 18:1 |
#
# Sin embargo, hay que tener en cuenta que las muestras aumentadas **no son independientes**: todas derivan de las mismas 56 grabaciones originales, por lo que el límite real de información del dataset no varía. El objetivo sigue siendo el mismo: demostrar empíricamente el rendimiento del baseline con MFCC chunkeados, ahora con el beneficio del data augmentation.

# %%
import pickle
import numpy as np
import pandas as pd

#Tablas y Gráficos
import matplotlib.pyplot as plt
import seaborn as sns

#Preprocesado
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

#Modelos
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif, VarianceThreshold
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import PredefinedSplit
from lightgbm import LGBMClassifier

# %%
ruta_train = '../datos_entrenamiento/train_mfcc_chunked_aumentado.pkl'
ruta_test = '../datos_entrenamiento/test_mfcc_chunked_aumentado.pkl'

datos_train = pickle.load(open(ruta_train, 'rb'))
datos_test = pickle.load(open(ruta_test, 'rb'))

df_train = pd.DataFrame(datos_train)
df_test = pd.DataFrame(datos_test)

print("Forma del Dataset de entrenamiento:", df_train.shape)
print()
print("Encontrar datos nulos --->", df_train.isnull().sum())
print()
print("¿Hay valores nulos?: ", df_train.isnull().any().any())

print("Forma del Dataset de test:", df_test.shape)
print()
print("Encontrar datos nulos --->", df_test.isnull().sum())
print()
print("¿Hay valores nulos?: ", df_test.isnull().any().any())
# Out:
# Forma del Dataset de entrenamiento: (4296, 5)
#
# Encontrar datos nulos ---> nombre_archivo    0
# mfccs             0
# caja_toracica     0
# grupo             0
# fold              0
# dtype: int64
#
# ¿Hay valores nulos?:  False
# Forma del Dataset de test: (247, 5)
#
# Encontrar datos nulos ---> nombre_archivo    0
# mfccs             0
# caja_toracica     0
# grupo             0
# fold              0
# dtype: int64
#
# ¿Hay valores nulos?:  False

# %%
df_train.head()
# Out:
#                                   nombre_archivo  \
# 0  Asma con CPAP urgencias_chunk000_original.wav
# 1     Asma con CPAP urgencias_chunk000_noise.wav
# 2     Asma con CPAP urgencias_chunk000_pitch.wav
# 3   Asma con CPAP urgencias_chunk000_stretch.wav
# 4  Asma con CPAP urgencias_chunk001_original.wav
#
#                                                mfccs caja_toracica  \
# 0  [[-712.71356, -712.71356, -712.71356, -712.713...   Obstructivo
# 1  [[-505.56918, -465.57983, -459.63614, -462.023...   Obstructivo
# 2  [[-697.9274, -697.9274, -697.9274, -696.8955, ...   Obstructivo
# 3  [[-720.2949, -720.2949, -720.2949, -719.193, -...   Obstructivo
# 4  [[-203.88815, -270.47705, -286.45206, -290.259...   Obstructivo
#
#                   grupo  fold
# 0  Ventilación Invasiva     0
# 1  Ventilación Invasiva     0
# 2  Ventilación Invasiva     0
# 3  Ventilación Invasiva     0
# 4  Ventilación Invasiva     0

# %% [markdown]
# Al igual que en el notebook de datos chunkeados, todas las entradas tienen la misma dimensionalidad de entrada gracias al preprocesado previo (segmentación a 10 segundos y padding aplicado al time stretch para garantizar uniformidad). Las muestras aumentadas conservan la misma forma MFCC que las originales: **(30 coeficientes × 1001 frames)**.

# %% [markdown]
# ## Extracción Características

# %% [markdown]
# Al igual que en el notebook anterior, necesitamos transformar las matrices MFCC (30 × 1001) en vectores unidimensionales para poder trabajar con modelos clásicos de ML. Aplicaremos las dos mismas estrategias:
#
# - **Mean+Std pooling**: comprime cada muestra en 60 características (30 medias + 30 desviaciones típicas). Mitiga la maldición de la dimensionalidad y es la representación más robusta para datasets de tamaño moderado.
# - **Flatten completo**: genera ~30.030 características por muestra. Con 4296 muestras la relación muestras/características mejora significativamente respecto al notebook anterior, aunque sigue siendo necesario aplicar reducción agresiva (PCA o SelectKBest).

# %%
def generar_datasets_aplanados(df):
    metadatos = df[['nombre_archivo', 'grupo', 'caja_toracica', 'fold']]
    n_mfcc = df['mfccs'].iloc[0].shape[0]

    # Dataset 1: Mean + Std (60 features)
    medias = pd.DataFrame(
        df['mfccs'].apply(lambda x: np.mean(x, axis=1)).tolist(),
        columns=[f'mfcc_media_{i+1}' for i in range(n_mfcc)],
        index=df.index
    )
    stds = pd.DataFrame(
        df['mfccs'].apply(lambda x: np.std(x, axis=1)).tolist(),
        columns=[f'mfcc_std_{i+1}' for i in range(n_mfcc)],
        index=df.index
    )
    df_pooling = pd.concat([metadatos, medias, stds], axis=1)

    # Dataset 2: Flatten completo (~30k features)
    df_flatten_features = pd.DataFrame(
        df['mfccs'].apply(lambda x: x.flatten()).tolist(),
        index=df.index
    )
    df_flatten = pd.concat([metadatos, df_flatten_features], axis=1)

    return df_pooling, df_flatten

df_train_pool, df_train_flat = generar_datasets_aplanados(df_train)
df_test_pool, df_test_flat = generar_datasets_aplanados(df_test)

# %%
print(f"Shape Train Plano: {df_train_flat.shape} + Shape Test Plano: {df_test_flat.shape}")
print(f"Shape Train Pooleado: {df_train_pool.shape} + Shape Test Pooleado: {df_test_pool.shape}")
# Out:
# Shape Train Plano: (4296, 30034) + Shape Test Plano: (247, 30034)
# Shape Train Pooleado: (4296, 64) + Shape Test Pooleado: (247, 64)

# %% [markdown]
# ### Extracción Características + Modelos DF_FLAT
#
# Comenzamos con el dataset flat (~30.030 características). Al igual que en el notebook anterior, el coste de calcular la matriz de correlación completa es demasiado elevado, por lo que aplicamos directamente VarianceThreshold como primer filtro, seguido de PCA y SelectKBest en experimentos independientes.

# %%
columnas_a_quitar = ['nombre_archivo', 'grupo', 'caja_toracica', 'fold']

X_train_num = df_train_flat.drop(columns=columnas_a_quitar)
X_test_num = df_test_flat.drop(columns=columnas_a_quitar)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_num)
X_test_scaled = scaler.transform(X_test_num)

selector = VarianceThreshold(threshold=0.1)
X_train_filtered = selector.fit_transform(X_train_scaled)
X_test_filtered = selector.transform(X_test_scaled)

print(f"Features originales: {X_train_scaled.shape[1]} → tras VarianceThreshold: {X_train_filtered.shape[1]}")
# Out:
# Features originales: 30030 → tras VarianceThreshold: 30030

# %% [markdown]
# Como en el notebook anterior, VarianceThreshold no reduce la dimensionalidad, por lo que pasamos directamente a PCA y SelectKBest en experimentos separados.

# %% [markdown]
# #### PCA en FLAT

# %%
scaler = StandardScaler()
subset_X = df_train_flat.drop(columns=columnas_a_quitar)
df_train_flat_transformed = scaler.fit_transform(subset_X)

pca = PCA()
df_train_pca = pca.fit_transform(df_train_flat_transformed)

cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
print(cumulative_variance)

# %% [markdown]
# Analizamos cuántos componentes son necesarios para explicar distintos porcentajes de varianza.

# %%
n_components_base = df_train_flat.drop(columns=columnas_a_quitar).shape[1]
print(f"Nº Componentes de base: {n_components_base}")

for umbral in [0.95, 0.90, 0.88, 0.85, 0.80, 0.75]:
    n = np.argmax(cumulative_variance >= umbral)
    print(f"Componentes necesarios para explicar el {int(umbral*100)}%: {n}")

# %% [markdown]
# Con el dataset aumentado (4296 muestras) la distribución de varianza puede diferir ligeramente respecto a las 1074 muestras originales. Al igual que en el notebook anterior, elegimos un número fijo de componentes que mantenga una relación muestras/características razonable, priorizando la viabilidad del entrenamiento frente a la varianza explicada.

# %%
print(f"Varianza explicada con 150 componentes: {cumulative_variance[149]:.4f}")

# %% [markdown]
# Trabajaremos con el número de componentes que representan el 45% de la varianza, manteniendo la misma decisión que en el notebook de datos no aumentados para facilitar la comparación de resultados.

# %%
scaler = StandardScaler()
X_train_num = df_train_flat.drop(columns=columnas_a_quitar)
X_test_num = df_test_flat.drop(columns=columnas_a_quitar)

X_train_scaled = scaler.fit_transform(X_train_num)
X_test_scaled = scaler.transform(X_test_num)

n_componentes = 0.45
pca = PCA(n_components=n_componentes, random_state=42)
X_train_pca_flat = pca.fit_transform(X_train_scaled)
X_test_pca_flat = pca.transform(X_test_scaled)

n_componentes_finales = X_train_pca_flat.shape[1]
print(f"El PCA ha seleccionado {n_componentes_finales} componentes principales.")

df_pca_train_flat = pd.DataFrame(
    X_train_pca_flat,
    columns=[f'MFCC_flat_pca{i+1}' for i in range(n_componentes_finales)],
    index=df_train_flat.index
)
df_train_flat_1 = pd.concat([df_train_flat[columnas_a_quitar], df_pca_train_flat], axis=1)

df_pca_test_flat = pd.DataFrame(
    X_test_pca_flat,
    columns=[f'MFCC_flat_pca{i+1}' for i in range(n_componentes_finales)],
    index=df_test_flat.index
)
df_test_flat_1 = pd.concat([df_test_flat[columnas_a_quitar], df_pca_test_flat], axis=1)

print("\nVista previa del conjunto de ENTRENAMIENTO post-pca:")
display(df_train_flat_1.head())

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=df_train_flat_1,
    x='MFCC_flat_pca1',
    y='MFCC_flat_pca2',
    hue='grupo',
    style='grupo',
    s=40,
    alpha=0.4
)
plt.title('Separabilidad tras PCA (2D) — Grupo Clínico (Aumentado)', fontsize=15, fontweight='bold')
plt.xlabel('Componente Principal 1', fontsize=12)
plt.ylabel('Componente Principal 2', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Grupo Clínico')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=df_train_flat_1,
    x='MFCC_flat_pca1',
    y='MFCC_flat_pca2',
    hue='caja_toracica',
    style='caja_toracica',
    s=40,
    alpha=0.4
)
plt.title('Separabilidad tras PCA (2D) — Caja Torácica (Aumentado)', fontsize=15, fontweight='bold')
plt.xlabel('Componente Principal 1', fontsize=12)
plt.ylabel('Componente Principal 2', fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Caja Torácica')
plt.tight_layout()
plt.show()

# %% [markdown]
# Los gráficos de dispersión muestran los dos primeros componentes principales sobre las 4296 muestras aumentadas. La mayor densidad de puntos hace más difícil la visualización, pero la ausencia de nubes separadas por clase confirma que la separabilidad lineal sigue siendo baja con este tipo de representación, al igual que en el notebook de datos originales.

# %% [markdown]
# #### Entrenamiento Modelos Flat con PCA
#
# Aplicamos RF, SVM y LightGBM sobre las componentes PCA. Para cada modelo mostramos los resultados con hiperparámetros por defecto. Con el dataset aumentado esperamos observar si el mayor volumen de datos de entrenamiento mejora la capacidad de generalización de los modelos.

# %%
def evaluar_modelo_pca_flat(grid_grupo, grid_caja, nombre_modelo):
    print(f"Mejores Hiperparámetros para Grupo Clínico: {grid_grupo.best_params_}")
    print(f"Mejores Hiperparámetros para Torácica: {grid_caja.best_params_}")

    pred_grupo = grid_grupo.predict(X_test_model)
    pred_caja = grid_caja.predict(X_test_model)

    acc_grupo = accuracy_score(y_test_grupo, pred_grupo)
    f1_grupo = f1_score(y_test_grupo, pred_grupo, average='macro', zero_division=0)
    print(f"GRUPOS -> Accuracy: {acc_grupo*100:.2f}% | F1-Score (Macro): {f1_grupo*100:.2f}%")

    acc_caja = accuracy_score(y_test_caja, pred_caja)
    f1_caja = f1_score(y_test_caja, pred_caja, average='macro', zero_division=0)
    print(f"CAJA TORÁCICA -> Accuracy: {acc_caja*100:.2f}% | F1-Score (Macro): {f1_caja*100:.2f}%")

    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle(f'Matrices de Confusión - {nombre_modelo}', fontsize=16, fontweight='bold')

    cm_grupo = confusion_matrix(y_test_grupo, pred_grupo, labels=grid_grupo.classes_)
    sns.heatmap(cm_grupo, annot=True, fmt='d', cmap='Blues', ax=axes[0],
                xticklabels=grid_grupo.classes_, yticklabels=grid_grupo.classes_)
    axes[0].set_title('Predicción: Grupo Clínico')
    axes[0].set_ylabel('Etiqueta Real')
    axes[0].set_xlabel('Predicción')
    axes[0].tick_params(axis='x', rotation=45)

    cm_caja = confusion_matrix(y_test_caja, pred_caja, labels=grid_caja.classes_)
    sns.heatmap(cm_caja, annot=True, fmt='d', cmap='Greens', ax=axes[1],
                xticklabels=grid_caja.classes_, yticklabels=grid_caja.classes_)
    axes[1].set_title('Predicción: Caja Torácica')
    axes[1].set_ylabel('Etiqueta Real')
    axes[1].set_xlabel('Predicción')
    axes[1].tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

# %%
columnas_pca = [col for col in df_train_flat_1.columns if 'pca' in col]

X_train_model = df_train_flat_1[columnas_pca]
X_test_model = df_test_flat_1[columnas_pca]

y_train_grupo = df_train_flat_1['grupo']
y_test_grupo = df_test_flat_1['grupo']

y_train_caja = df_train_flat_1['caja_toracica']
y_test_caja = df_test_flat_1['caja_toracica']

# %%
folds_oficiales = df_train_flat_1['fold'].values
ps = PredefinedSplit(test_fold=folds_oficiales)

# %% [markdown]
# ##### Random Forest

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
param_grid_rf = {
    'n_estimators': [100],
    'max_depth': [None],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'max_features': ['sqrt'],
    'bootstrap': [True]
}

rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_model, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pca_flat(grid_rf_grupo, grid_rf_caja, "Random Forest - PCA - Flat - Aumentado")

# %% [markdown]
# ##### SVM

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
param_grid_svm = {
    'C': [1.0],
    'kernel': ['rbf'],
    'gamma': ['scale']
}

svm_base_grupo = SVC(class_weight='balanced', random_state=42)
grid_svm_grupo = GridSearchCV(svm_base_grupo, param_grid_svm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_grupo.fit(X_train_model, y_train_grupo)

svm_base_caja = SVC(class_weight='balanced', random_state=42)
grid_svm_caja = GridSearchCV(svm_base_caja, param_grid_svm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pca_flat(grid_svm_grupo, grid_svm_caja, "SVM - PCA - Flat - Aumentado")

# %% [markdown]
# ##### LightGBM

# %%
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html
param_grid_lgbm = {
    'n_estimators': [100],
    'learning_rate': [0.1],
    'num_leaves': [31],
    'max_depth': [-1],
    'min_child_samples': [20]
}

lgbm_base_grupo = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_grupo = GridSearchCV(lgbm_base_grupo, param_grid_lgbm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_grupo.fit(X_train_model, y_train_grupo)

lgbm_base_caja = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_caja = GridSearchCV(lgbm_base_caja, param_grid_lgbm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pca_flat(grid_lgbm_grupo, grid_lgbm_caja, "LightGBM - PCA - Flat - Aumentado")

# %% [markdown]
# #### SelectKBest en FLAT
#
# Selección supervisada de características mediante ANOVA F-test, independiente para cada objetivo. Con 4296 muestras y 75 características seleccionadas, la relación 4296/75 ≈ 57:1 es muy favorable para modelos clásicos.

# %%
columnas_a_quitar = ['nombre_archivo', 'grupo', 'caja_toracica', 'fold']

X_train_num = df_train_flat.drop(columns=columnas_a_quitar)
X_test_num = df_test_flat.drop(columns=columnas_a_quitar)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_num)
X_test_scaled = scaler.transform(X_test_num)

meta_train = df_train_flat[columnas_a_quitar].reset_index(drop=True)
meta_test = df_test_flat[columnas_a_quitar].reset_index(drop=True)

# %%
y_train_grupo = meta_train['grupo']
y_test_grupo = meta_test['grupo']

y_train_caja = meta_train['caja_toracica']
y_test_caja = meta_test['caja_toracica']

K_FEATURES = 75
# Seleccionamos 75 características. Con 4296 muestras la relación muestras/características
# (≈57:1) es muy favorable. Al ser SelectKBest supervisado (ANOVA F-test), estas 75
# características son las de mayor correlación estadística con la variable objetivo,
# a diferencia del PCA que opera de forma no supervisada.

selector_grupo = SelectKBest(score_func=f_classif, k=K_FEATURES)
X_train_grupo_selected = selector_grupo.fit_transform(X_train_scaled, y_train_grupo)
X_test_grupo_selected = selector_grupo.transform(X_test_scaled)

selector_caja = SelectKBest(score_func=f_classif, k=K_FEATURES)
X_train_caja_selected = selector_caja.fit_transform(X_train_scaled, y_train_caja)
X_test_caja_selected = selector_caja.transform(X_test_scaled)

X_train_grupo_selected = np.array(X_train_grupo_selected)
X_test_grupo_selected  = np.array(X_test_grupo_selected)
X_train_caja_selected  = np.array(X_train_caja_selected)
X_test_caja_selected   = np.array(X_test_caja_selected)

# %% [markdown]
# #### Entrenamiento de modelos

# %%
def evaluar_modelo_kbest_flat(grid_grupo, grid_caja, X_test_grupo, X_test_caja, nombre_modelo):
    print(f"Mejores Hiperparámetros para Grupo Clínico: {grid_grupo.best_params_}")
    print(f"Mejores Hiperparámetros para Torácica: {grid_caja.best_params_}")

    pred_grupo = grid_grupo.predict(X_test_grupo)
    pred_caja = grid_caja.predict(X_test_caja)

    acc_grupo = accuracy_score(y_test_grupo, pred_grupo)
    f1_grupo = f1_score(y_test_grupo, pred_grupo, average='macro', zero_division=0)
    print(f"GRUPOS -> Accuracy: {acc_grupo*100:.2f}% | F1-Score (Macro): {f1_grupo*100:.2f}%")

    acc_caja = accuracy_score(y_test_caja, pred_caja)
    f1_caja = f1_score(y_test_caja, pred_caja, average='macro', zero_division=0)
    print(f"CAJA TORÁCICA -> Accuracy: {acc_caja*100:.2f}% | F1-Score (Macro): {f1_caja*100:.2f}%")

    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle(f'Matrices de Confusión - {nombre_modelo}', fontsize=16, fontweight='bold')

    cm_grupo = confusion_matrix(y_test_grupo, pred_grupo, labels=grid_grupo.classes_)
    sns.heatmap(cm_grupo, annot=True, fmt='d', cmap='Blues', ax=axes[0],
                xticklabels=grid_grupo.classes_, yticklabels=grid_grupo.classes_)
    axes[0].set_title('Predicción: Grupo Clínico')
    axes[0].set_ylabel('Etiqueta Real')
    axes[0].set_xlabel('Predicción')
    axes[0].tick_params(axis='x', rotation=45)

    cm_caja = confusion_matrix(y_test_caja, pred_caja, labels=grid_caja.classes_)
    sns.heatmap(cm_caja, annot=True, fmt='d', cmap='Greens', ax=axes[1],
                xticklabels=grid_caja.classes_, yticklabels=grid_caja.classes_)
    axes[1].set_title('Predicción: Caja Torácica')
    axes[1].set_ylabel('Etiqueta Real')
    axes[1].set_xlabel('Predicción')
    axes[1].tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

# %%
folds_oficiales = df_train_flat['fold'].values
ps = PredefinedSplit(test_fold=folds_oficiales)

# %% [markdown]
# ##### Random Forest

# %%
param_grid_rf = {
    'n_estimators': [100],
    'max_depth': [None],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'max_features': ['sqrt'],
    'bootstrap': [True]
}

rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_grupo_selected, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(grid_rf_grupo, grid_rf_caja,
    X_test_grupo_selected, X_test_caja_selected,
    "Random Forest - SelectKBest=75 - Flat - Aumentado")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# GRUPOS -> Accuracy: 48.58% | F1-Score (Macro): 14.82%
# CAJA TORÁCICA -> Accuracy: 50.20% | F1-Score (Macro): 37.48%

# %%
param_grid_rf_1 = {
    'n_estimators': [100, 150],      
    'max_depth': [None, 10, 20],        
    'min_samples_split': [2, 5],   
    'min_samples_leaf': [1, 2],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}


#Entrenamos para cada objetivo
rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_grupo_selected, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_rf_grupo, 
    grid_caja=grid_rf_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="Random Forest - SelectKBest=75 - Flat - Aumentado"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# GRUPOS -> Accuracy: 49.39% | F1-Score (Macro): 20.02%
# CAJA TORÁCICA -> Accuracy: 48.18% | F1-Score (Macro): 30.52%

# %%
param_grid_rf_2_kbest = {
    'n_estimators': [100, 200],      
    'max_depth': [None, 10],        
    'min_samples_split': [2, 5],   
    'min_samples_leaf': [2, 6],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

#Entrenamos para cada objetivo
rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_2_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_grupo_selected, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_2_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_rf_grupo, 
    grid_caja=grid_rf_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="Random Forest - SelectKBest=75 - Flat - Aumentado"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# GRUPOS -> Accuracy: 54.66% | F1-Score (Macro): 22.44%
# CAJA TORÁCICA -> Accuracy: 44.94% | F1-Score (Macro): 28.12%

# %%
param_grid_rf_3_grupo_kbest = {
    'n_estimators': [200, 250],      
    'max_depth': [None],        
    'min_samples_split': [2],   
    'min_samples_leaf': [6, 8],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

"""
Config final rf grupo si da peor rendimiento:
param_grid_rf_2_kbest = {
    'n_estimators': [200],      
    'max_depth': [None],        
    'min_samples_split': [2],   
    'min_samples_leaf': [6],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}
"""

param_grid_rf_final_caja_kbest = {
    'n_estimators': [100],
    'max_depth': [None],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'max_features': ['sqrt'],
    'bootstrap': [True]    
}

#Entrenamos para cada objetivo
rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_3_grupo_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_grupo_selected, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_final_caja_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_rf_grupo, 
    grid_caja=grid_rf_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="Random Forest - SelectKBest=75 - Flat - Aumentado"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 200}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# GRUPOS -> Accuracy: 57.09% | F1-Score (Macro): 24.35%
# CAJA TORÁCICA -> Accuracy: 50.20% | F1-Score (Macro): 37.48%

# %%
param_grid_rf_4_grupo_kbest = {
    'n_estimators': [200, 300],      
    'max_depth': [None],        
    'min_samples_split': [2],   
    'min_samples_leaf': [8, 10],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

"""
Config final rf grupo si da peor rendimiento:
param_grid_rf_2_kbest = {
    'n_estimators': [200],      
    'max_depth': [None],        
    'min_samples_split': [2],   
    'min_samples_leaf': [8],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}
"""

param_grid_rf_final_caja_kbest = {
    'n_estimators': [100],
    'max_depth': [None],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'max_features': ['sqrt'],
    'bootstrap': [True]    
}

#Entrenamos para cada objetivo
rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_4_grupo_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_grupo_selected, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_final_caja_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_rf_grupo, 
    grid_caja=grid_rf_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="Random Forest - SelectKBest=75 - Flat - Aumentado"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 300}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# GRUPOS -> Accuracy: 58.30% | F1-Score (Macro): 26.46%
# CAJA TORÁCICA -> Accuracy: 50.20% | F1-Score (Macro): 37.48%

# %%
param_grid_rf_5_grupo_kbest = {
    'n_estimators': [300, 350],      
    'max_depth': [None],        
    'min_samples_split': [2],   
    'min_samples_leaf': [8],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

"""
Config final rf grupo si da peor rendimiento:
param_grid_rf_final_grupo_kbest = {
    'n_estimators': [300],      
    'max_depth': [None],        
    'min_samples_split': [2],   
    'min_samples_leaf': [8],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}
"""
"""
param_grid_rf_final_caja_kbest = {
    'n_estimators': [100],
    'max_depth': [None],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'max_features': ['sqrt'],
    'bootstrap': [True]    
}
"""

#Viendo que con grupo podemos obtener tan buen rendimiento, probaremos a seguir haciendo tuneo de caja.
param_grid_rf_3_caja_kbest = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None],
    'min_samples_split': [2],
    'min_samples_leaf': [6, 8],
    'max_features': ['sqrt'],
    'bootstrap': [True]    
}

#Entrenamos para cada objetivo
rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_5_grupo_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_grupo_selected, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_3_caja_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_rf_grupo, 
    grid_caja=grid_rf_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="Random Forest - SelectKBest=75 - Flat - Aumentado"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 350}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200}
# GRUPOS -> Accuracy: 56.68% | F1-Score (Macro): 25.62%
# CAJA TORÁCICA -> Accuracy: 46.15% | F1-Score (Macro): 27.50%

# %%
param_grid_rf_final_grupo_kbest = {
    'n_estimators': [300],      
    'max_depth': [None],        
    'min_samples_split': [2],   
    'min_samples_leaf': [8],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

param_grid_rf_final_caja_kbest = {
    'n_estimators': [100],
    'max_depth': [None],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'max_features': ['sqrt'],
    'bootstrap': [True]    
}

rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_final_grupo_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_grupo_selected, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_final_caja_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_rf_grupo, 
    grid_caja=grid_rf_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="Random Forest - SelectKBest=75 - Flat - Aumentado"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 300}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# GRUPOS -> Accuracy: 58.30% | F1-Score (Macro): 26.46%
# CAJA TORÁCICA -> Accuracy: 50.20% | F1-Score (Macro): 37.48%

# %% [markdown]
# ##### SVM

# %%
param_grid_svm = {
    'C': [1.0],
    'kernel': ['rbf'],
    'gamma': ['scale']
}

svm_base_grupo = SVC(class_weight='balanced', random_state=42)
grid_svm_grupo = GridSearchCV(svm_base_grupo, param_grid_svm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_grupo.fit(X_train_grupo_selected, y_train_grupo)

svm_base_caja = SVC(class_weight='balanced', random_state=42)
grid_svm_caja = GridSearchCV(svm_base_caja, param_grid_svm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(grid_svm_grupo, grid_svm_caja,
    X_test_grupo_selected, X_test_caja_selected,
    "SVM - SelectKBest=75 - Flat - Aumentado")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# Mejores Hiperparámetros para Torácica: {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# GRUPOS -> Accuracy: 40.49% | F1-Score (Macro): 24.75%
# CAJA TORÁCICA -> Accuracy: 36.03% | F1-Score (Macro): 20.08%

# %%
param_grid_svm_1 = {
    'C': [0.5, 1.0, 1.5],
    'kernel': ['rbf'],
    'gamma': ['scale']
}

svm_base_grupo = SVC(class_weight='balanced', random_state=42)
grid_svm_grupo = GridSearchCV(svm_base_grupo, param_grid_svm_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_grupo.fit(X_train_grupo_selected, y_train_grupo)

svm_base_caja = SVC(class_weight='balanced', random_state=42)
grid_svm_caja = GridSearchCV(svm_base_caja, param_grid_svm_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_svm_grupo, 
    grid_caja=grid_svm_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="SVM - SelectKBest=75 - Flat"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'C': 1.5, 'gamma': 'scale', 'kernel': 'rbf'}
# Mejores Hiperparámetros para Torácica: {'C': 0.5, 'gamma': 'scale', 'kernel': 'rbf'}
# GRUPOS -> Accuracy: 44.53% | F1-Score (Macro): 26.76%
# CAJA TORÁCICA -> Accuracy: 31.17% | F1-Score (Macro): 17.20%

# %%
param_grid_svm_2_grupo_kbest = {
    'C': [1.5, 2.0],
    'kernel': ['rbf'],
    'gamma': ['scale']
}

param_grid_svm_2_caja_kbest = {
    'C': [1.0, 2.0],
    'kernel': ['rbf'],
    'gamma': ['scale']
}
svm_base_grupo = SVC(class_weight='balanced', random_state=42)
grid_svm_grupo = GridSearchCV(svm_base_grupo, param_grid_svm_2_grupo_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_grupo.fit(X_train_grupo_selected, y_train_grupo)

svm_base_caja = SVC(class_weight='balanced', random_state=42)
grid_svm_caja = GridSearchCV(svm_base_caja, param_grid_svm_2_caja_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_svm_grupo, 
    grid_caja=grid_svm_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="SVM - SelectKBest=75 - Flat"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'C': 1.5, 'gamma': 'scale', 'kernel': 'rbf'}
# Mejores Hiperparámetros para Torácica: {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# GRUPOS -> Accuracy: 44.53% | F1-Score (Macro): 26.76%
# CAJA TORÁCICA -> Accuracy: 36.03% | F1-Score (Macro): 20.08%

# %%
param_grid_svm_final_grupo_kbest = {
    'C': [1.5],
    'kernel': ['rbf'],
    'gamma': ['scale']
}

param_grid_svm_final_caja_kbest = {
    'C': [1.0],
    'kernel': ['rbf'],
    'gamma': ['scale']
}
svm_base_grupo = SVC(class_weight='balanced', random_state=42)
grid_svm_grupo = GridSearchCV(svm_base_grupo, param_grid_svm_final_grupo_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_grupo.fit(X_train_grupo_selected, y_train_grupo)

svm_base_caja = SVC(class_weight='balanced', random_state=42)
grid_svm_caja = GridSearchCV(svm_base_caja, param_grid_svm_final_caja_kbest, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_svm_grupo, 
    grid_caja=grid_svm_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="SVM - SelectKBest=75 - Flat"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'C': 1.5, 'gamma': 'scale', 'kernel': 'rbf'}
# Mejores Hiperparámetros para Torácica: {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# GRUPOS -> Accuracy: 44.53% | F1-Score (Macro): 26.76%
# CAJA TORÁCICA -> Accuracy: 36.03% | F1-Score (Macro): 20.08%

# %% [markdown]
# ##### LightGBM

# %%
param_grid_lgbm = {
    'n_estimators': [100],
    'learning_rate': [0.1],
    'num_leaves': [31],
    'max_depth': [-1],
    'min_child_samples': [20]
}

lgbm_base_grupo = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_grupo = GridSearchCV(lgbm_base_grupo, param_grid_lgbm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_grupo.fit(X_train_grupo_selected, y_train_grupo)

lgbm_base_caja = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_caja = GridSearchCV(lgbm_base_caja, param_grid_lgbm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(grid_lgbm_grupo, grid_lgbm_caja,
    X_test_grupo_selected, X_test_caja_selected,
    "LightGBM - SelectKBest=75 - Flat - Aumentado")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 31}
# Mejores Hiperparámetros para Torácica: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 31}
# GRUPOS -> Accuracy: 57.09% | F1-Score (Macro): 23.16%
# CAJA TORÁCICA -> Accuracy: 41.70% | F1-Score (Macro): 23.95%
# C:\Users\pedro\anaconda3\envs\env_audio\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\pedro\anaconda3\envs\env_audio\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
param_grid_lgbm_1 = {
    'n_estimators': [100, 200],
    'learning_rate': [0.05, 0.1],
    'num_leaves': [31, 63],
    'max_depth': [-1, 10],
    'min_child_samples': [20, 50]
}

lgbm_base_grupo = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_grupo = GridSearchCV(lgbm_base_grupo, param_grid_lgbm_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_grupo.fit(X_train_grupo_selected, y_train_grupo)

lgbm_base_caja = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_caja = GridSearchCV(lgbm_base_caja, param_grid_lgbm_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_lgbm_grupo, 
    grid_caja=grid_lgbm_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="LightGBM - SelectKBest=75 - Flat"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'learning_rate': 0.1, 'max_depth': 10, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 63}
# Mejores Hiperparámetros para Torácica: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 200, 'num_leaves': 31}
# GRUPOS -> Accuracy: 54.66% | F1-Score (Macro): 21.85%
# CAJA TORÁCICA -> Accuracy: 42.91% | F1-Score (Macro): 32.33%
# C:\Users\pedro\anaconda3\envs\env_audio\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\pedro\anaconda3\envs\env_audio\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
param_grid_lgbm_2_grupo_kbest_flat = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.1, 0.15],
    'num_leaves': [31, 63],
    'max_depth': [-1],
    'min_child_samples': [20]
}

param_grid_lgbm_2_caja_kbest_flat = {
    'n_estimators': [200, 300],
    'learning_rate': [0.1, 0.15],
    'num_leaves': [31],
    'max_depth': [-1],
    'min_child_samples': [20]
}


lgbm_base_grupo = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_grupo = GridSearchCV(lgbm_base_grupo, param_grid_lgbm_2_grupo_kbest_flat, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_grupo.fit(X_train_grupo_selected, y_train_grupo)

lgbm_base_caja = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_caja = GridSearchCV(lgbm_base_caja, param_grid_lgbm_2_caja_kbest_flat, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_lgbm_grupo, 
    grid_caja=grid_lgbm_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="LightGBM - SelectKBest=75 - Flat"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'learning_rate': 0.15, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 31}
# Mejores Hiperparámetros para Torácica: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 200, 'num_leaves': 31}
# GRUPOS -> Accuracy: 55.87% | F1-Score (Macro): 22.13%
# CAJA TORÁCICA -> Accuracy: 42.91% | F1-Score (Macro): 32.33%
# C:\Users\pedro\anaconda3\envs\env_audio\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\pedro\anaconda3\envs\env_audio\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
param_grid_lgbm_3_grupo_kbest_flat = {
    'n_estimators': [100, 200],
    'learning_rate': [0.15, 0.2],
    'num_leaves': [31],
    'max_depth': [-1],
    'min_child_samples': [20]
}

param_grid_lgbm_final_caja_kbest_flat = {
    'n_estimators': [200],
    'learning_rate': [0.1],
    'num_leaves': [31],
    'max_depth': [-1],
    'min_child_samples': [20]
}


lgbm_base_grupo = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_grupo = GridSearchCV(lgbm_base_grupo, param_grid_lgbm_3_grupo_kbest_flat, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_grupo.fit(X_train_grupo_selected, y_train_grupo)

lgbm_base_caja = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_caja = GridSearchCV(lgbm_base_caja, param_grid_lgbm_final_caja_kbest_flat, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_caja.fit(X_train_caja_selected, y_train_caja)

evaluar_modelo_kbest_flat(
    grid_grupo=grid_lgbm_grupo, 
    grid_caja=grid_lgbm_caja, 
    X_test_grupo=X_test_grupo_selected,
    X_test_caja=X_test_caja_selected,   
    nombre_modelo="LightGBM - SelectKBest=75 - Flat"
)
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'learning_rate': 0.15, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 31}
# Mejores Hiperparámetros para Torácica: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 200, 'num_leaves': 31}
# GRUPOS -> Accuracy: 55.87% | F1-Score (Macro): 22.13%
# CAJA TORÁCICA -> Accuracy: 42.91% | F1-Score (Macro): 32.33%
# C:\Users\pedro\anaconda3\envs\env_audio\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\pedro\anaconda3\envs\env_audio\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Extracción Características + Modelos DF_POOL
#
# El dataset pooleado (mean+std) tiene 60 características por muestra. Con 4296 muestras de entrenamiento, la relación 4296/60 ≈ 72:1 es excelente. Aplicamos el mismo análisis de correlación que en el notebook anterior para eliminar características redundantes antes del entrenamiento.

# %%
columnas_a_quitar = ['nombre_archivo', 'grupo', 'caja_toracica', 'fold']

X_train = df_train_pool.drop(columns=columnas_a_quitar)

corr_matrix = X_train.corr()

def plot_corr(df, title):
    plt.figure(figsize=(10, 8))
    sns.heatmap(df.corr(), cmap='coolwarm', center=0)
    plt.title(f"Correlación - {title}")
    plt.show()

plot_corr(X_train, "MFCCs Pooleados (mean+std) - Aumentado")

# %%
columnas_correlacionadas = [f'mfcc_std_{i}' for i in range(1, 31)]
X_correlacionado = X_train[columnas_correlacionadas]

umbral = 0.8
matriz_corr_sub = X_correlacionado.corr()
for i in range(len(matriz_corr_sub.columns)):
    for j in range(i):
        col1 = matriz_corr_sub.columns[i]
        col2 = matriz_corr_sub.columns[j]
        correlacion = matriz_corr_sub.iloc[i, j]
        if correlacion >= umbral:
            print(f"{col1} y {col2} -> Correlación: {correlacion:.3f}")
# Out:
# mfcc_std_2 y mfcc_std_1 -> Correlación: 0.839
# mfcc_std_23 y mfcc_std_22 -> Correlación: 0.892
# mfcc_std_24 y mfcc_std_22 -> Correlación: 0.824
# mfcc_std_24 y mfcc_std_23 -> Correlación: 0.889
# mfcc_std_25 y mfcc_std_23 -> Correlación: 0.802
# mfcc_std_25 y mfcc_std_24 -> Correlación: 0.893
# mfcc_std_26 y mfcc_std_25 -> Correlación: 0.853
# mfcc_std_27 y mfcc_std_25 -> Correlación: 0.824
# mfcc_std_27 y mfcc_std_26 -> Correlación: 0.879
# mfcc_std_28 y mfcc_std_27 -> Correlación: 0.894
# mfcc_std_29 y mfcc_std_28 -> Correlación: 0.809
# mfcc_std_30 y mfcc_std_28 -> Correlación: 0.815
# mfcc_std_30 y mfcc_std_29 -> Correlación: 0.816

# %% [markdown]
# Con esto podemos ver que hay muchas características que tienen más del 80% de correlación, sin embargo, muy pocas son las que superan el 85% y solo una pareja supera el 90%. En este caso, vamos a eliminar aquellas características que superen el 88% de correlación, tratándose de un valor elevado que nos permite reducir la redundancia entre características altamente correlacionadas sin perder información relevante. De este modo, mantenemos la mayor parte de la varianza del espacio original mientras eliminamos únicamente aquellos pares de características que aportan información prácticamente idéntica al modelo.

# %%
umbral = 0.88
pares_a_eliminar = set()

matriz_correlacion = X_train.corr()
for i in range(len(matriz_correlacion.columns)):
    for j in range(i):
        if abs(matriz_correlacion.iloc[i, j]) > umbral:
            col1 = matriz_correlacion.columns[i]
            col2 = matriz_correlacion.columns[j]
            correlacion = matriz_correlacion.iloc[i, j]
            print(f"{col1} y {col2} -> Correlación: {correlacion:.3f}")
            pares_a_eliminar.add(col1)

print("Columnas a eliminar: ")
print(f"{list(pares_a_eliminar)}. Número total = {len(pares_a_eliminar)}")

X_pool_reducido_train = df_train_pool.drop(columns=pares_a_eliminar)
X_pool_reducido_test = df_test_pool.drop(columns=pares_a_eliminar)
# Out:
# mfcc_std_23 y mfcc_std_22 -> Correlación: 0.892
# mfcc_std_24 y mfcc_std_23 -> Correlación: 0.889
# mfcc_std_25 y mfcc_std_24 -> Correlación: 0.893
# mfcc_std_28 y mfcc_std_27 -> Correlación: 0.894
# Columnas a eliminar:
# ['mfcc_std_25', 'mfcc_std_28', 'mfcc_std_23', 'mfcc_std_24']. Número total = 4

# %%
X_pool_reducido_train.head()
# Out:
#                                   nombre_archivo                 grupo  \
# 0  Asma con CPAP urgencias_chunk000_original.wav  Ventilación Invasiva
# 1     Asma con CPAP urgencias_chunk000_noise.wav  Ventilación Invasiva
# 2     Asma con CPAP urgencias_chunk000_pitch.wav  Ventilación Invasiva
# 3   Asma con CPAP urgencias_chunk000_stretch.wav  Ventilación Invasiva
# 4  Asma con CPAP urgencias_chunk001_original.wav  Ventilación Invasiva
#
#   caja_toracica  fold  mfcc_media_1  mfcc_media_2  mfcc_media_3  mfcc_media_4  \
# 0   Obstructivo     0   -352.684570    121.787636      6.224621     27.935034
# 1   Obstructivo     0   -319.283417     91.671692     20.068008     17.452246
# 2   Obstructivo     0   -374.127502    117.942337      3.405392     23.009089
# 3   Obstructivo     0   -331.996765    105.976959      4.271125     23.123791
# 4   Obstructivo     0   -339.487823    123.426231      9.730461     32.741390
#
#    mfcc_media_5  mfcc_media_6  ...  mfcc_std_17  mfcc_std_18  mfcc_std_19  \
# 0     -5.439145    -12.892975  ...     8.444282     8.405086     7.996205
# 1     -0.050659    -14.547250  ...     7.863249     7.814464     7.685587
# 2    -14.711670    -15.873019  ...    10.219060     8.464773     8.474326
# 3     -3.691525    -13.280184  ...     8.294802     7.807930     7.688531
# 4      3.526648    -13.321842  ...     8.148713     8.455305     7.836003
#
#    mfcc_std_20  mfcc_std_21  mfcc_std_22  mfcc_std_26  mfcc_std_27  \
# 0     7.939536     8.150311     8.694556     9.260821     9.394863
# 1     7.504235     7.545633     8.356259     9.018554     8.654330
# 2     9.379758    10.026278     9.859919     8.461672     8.761015
# 3     7.501389     7.862662     8.152406     7.814067     8.338264
# 4     7.804312     8.876750     7.445955     7.528830     7.966033
#
#    mfcc_std_29  mfcc_std_30
# 0     8.406208     8.015336
# 1     8.038050     7.445850
# 2     8.882645     8.779788
# 3     7.556133     7.301164
# 4     8.578970     7.592166
#
# [5 rows x 60 columns]

# %%
X_pool_reducido_test.head()
# Out:
#                                       nombre_archivo                 grupo  \
# 0  Asma obesidad grave vni planta_chunk000_origin...  Ventilación Invasiva
# 1  Asma obesidad grave vni planta_chunk001_origin...  Ventilación Invasiva
# 2  Asma obesidad grave vni planta_chunk002_origin...  Ventilación Invasiva
# 3  Asma obesidad grave vni planta_chunk003_origin...  Ventilación Invasiva
# 4  Asma obesidad grave vni planta_chunk004_origin...  Ventilación Invasiva
#
#   caja_toracica  fold  mfcc_media_1  mfcc_media_2  mfcc_media_3  mfcc_media_4  \
# 0   Obstructivo    -1   -351.863068    106.542160      4.947843     13.515463
# 1   Obstructivo    -1   -393.288605    131.573517     -2.345975      5.945772
# 2   Obstructivo    -1   -365.639435    131.818985     -2.072165     16.053932
# 3   Obstructivo    -1   -393.031647    130.891052     -3.190361      1.497378
# 4   Obstructivo    -1   -388.963470    129.496872     -4.107275      0.907438
#
#    mfcc_media_5  mfcc_media_6  ...  mfcc_std_17  mfcc_std_18  mfcc_std_19  \
# 0     -9.535410      1.731867  ...     7.343532     7.285684     7.209405
# 1    -22.507574      3.990155  ...     7.086808     7.435338     7.038389
# 2    -15.497279      5.353491  ...     7.327020     7.831313     7.243642
# 3    -22.149729      5.697374  ...     7.620267     7.616788     7.390032
# 4    -20.780487      6.340427  ...     7.856251     7.979238     7.489220
#
#    mfcc_std_20  mfcc_std_21  mfcc_std_22  mfcc_std_26  mfcc_std_27  \
# 0     7.575176     7.960977     7.602012     7.451983     7.202028
# 1     7.185234     6.782732     6.558898     7.337729     7.652472
# 2     7.226472     6.781689     6.940420     7.758900     8.005737
# 3     8.201317     7.395317     7.481059     8.124797     7.900792
# 4     7.864351     7.285964     7.486277     8.965296     7.901580
#
#    mfcc_std_29  mfcc_std_30
# 0     7.094824     7.444332
# 1     8.119221     8.108114
# 2     7.901624     7.661132
# 3     7.295523     7.487084
# 4     7.593573     7.646188
#
# [5 rows x 60 columns]

# %% [markdown]
# En este caso, contamos con un número reducido de características con el que trabajar directamente, por lo que pasaremos al entrenamiento de modelos sin reducción adicional.

# %% [markdown]
# #### Entrenamiento de Modelos.

# %%
columnas_num = [col for col in X_pool_reducido_train.columns if 'mfcc' in col]

X_train_model = X_pool_reducido_train[columnas_num]
X_test_model = X_pool_reducido_test[columnas_num]

y_train_grupo = df_train_pool['grupo']
y_test_grupo = df_test_pool['grupo']

y_train_caja = df_train_pool['caja_toracica']
y_test_caja = df_test_pool['caja_toracica']

folds_oficiales = df_train_pool['fold'].values
ps = PredefinedSplit(test_fold=folds_oficiales)

def evaluar_modelo_pool(grid_grupo, grid_caja, nombre_modelo):
    print(f"Mejores Hiperparámetros para Grupo Clínico: {grid_grupo.best_params_}")
    print(f"Mejores Hiperparámetros para Torácica: {grid_caja.best_params_}")

    pred_grupo = grid_grupo.predict(X_test_model)
    pred_caja = grid_caja.predict(X_test_model)

    acc_grupo = accuracy_score(y_test_grupo, pred_grupo)
    f1_grupo = f1_score(y_test_grupo, pred_grupo, average='macro', zero_division=0)
    print(f"GRUPOS -> Accuracy: {acc_grupo*100:.2f}% | F1-Score (Macro): {f1_grupo*100:.2f}%")

    acc_caja = accuracy_score(y_test_caja, pred_caja)
    f1_caja = f1_score(y_test_caja, pred_caja, average='macro', zero_division=0)
    print(f"CAJA TORÁCICA -> Accuracy: {acc_caja*100:.2f}% | F1-Score (Macro): {f1_caja*100:.2f}%")

    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle(f'Matrices de Confusión - {nombre_modelo}', fontsize=16, fontweight='bold')

    cm_grupo = confusion_matrix(y_test_grupo, pred_grupo, labels=grid_grupo.classes_)
    sns.heatmap(cm_grupo, annot=True, fmt='d', cmap='Blues', ax=axes[0],
                xticklabels=grid_grupo.classes_, yticklabels=grid_grupo.classes_)
    axes[0].set_title('Predicción: Grupo Clínico')
    axes[0].set_ylabel('Etiqueta Real')
    axes[0].set_xlabel('Predicción')
    axes[0].tick_params(axis='x', rotation=45)

    cm_caja = confusion_matrix(y_test_caja, pred_caja, labels=grid_caja.classes_)
    sns.heatmap(cm_caja, annot=True, fmt='d', cmap='Greens', ax=axes[1],
                xticklabels=grid_caja.classes_, yticklabels=grid_caja.classes_)
    axes[1].set_title('Predicción: Caja Torácica')
    axes[1].set_ylabel('Etiqueta Real')
    axes[1].set_xlabel('Predicción')
    axes[1].tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### Random Forest

# %%
param_grid_rf = {
    'n_estimators': [100],
    'max_depth': [None],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'max_features': ['sqrt'],
    'bootstrap': [True]
}

rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_model, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_rf_grupo, grid_rf_caja, "Random Forest - Pool - Aumentado")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# GRUPOS -> Accuracy: 49.80% | F1-Score (Macro): 16.99%
# CAJA TORÁCICA -> Accuracy: 53.44% | F1-Score (Macro): 35.63%

# %%
param_grid_rf_1 = {
    'n_estimators': [100, 150],      
    'max_depth': [None, 10, 20],        
    'min_samples_split': [2, 5],   
    'min_samples_leaf': [1, 2],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

#Entrenamos para cada objetivo
rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_model, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_rf_grupo, grid_rf_caja, "Random Forest - Pool")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# GRUPOS -> Accuracy: 54.25% | F1-Score (Macro): 22.36%
# CAJA TORÁCICA -> Accuracy: 48.99% | F1-Score (Macro): 35.29%

# %%
param_grid_rf_2 = {
    'n_estimators': [100, 200],      
    'max_depth': [None],        
    'min_samples_split': [2, 5],   
    'min_samples_leaf': [2, 6],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

#Entrenamos para cada objetivo
rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_2, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_model, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_2, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_rf_grupo, grid_rf_caja, "Random Forest - Pool")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# GRUPOS -> Accuracy: 54.66% | F1-Score (Macro): 20.56%
# CAJA TORÁCICA -> Accuracy: 52.23% | F1-Score (Macro): 35.52%

# %%
param_grid_rf_3_grupo_pool = {
    'n_estimators': [100, 200, 300],      
    'max_depth': [None],        
    'min_samples_split': [2],   
    'min_samples_leaf': [2, 8],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

param_grid_rf_3_caja_pool = {
    'n_estimators': [100, 200, 300],      
    'max_depth': [None],        
    'min_samples_split': [5, 8],   
    'min_samples_leaf': [2, 8],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

#Entrenamos para cada objetivo
rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_3_grupo_pool, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_model, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_3_caja_pool, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_rf_grupo, grid_rf_caja, "Random Forest - Pool")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 300}
# GRUPOS -> Accuracy: 54.66% | F1-Score (Macro): 20.56%
# CAJA TORÁCICA -> Accuracy: 48.58% | F1-Score (Macro): 27.43%

# %%
param_grid_rf_final_grupo_pool = {
    'n_estimators': [100],      
    'max_depth': [None],        
    'min_samples_split': [2],   
    'min_samples_leaf': [2],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

param_grid_rf_final_caja_pool = {
    'n_estimators': [200],      
    'max_depth': [None],        
    'min_samples_split': [5],   
    'min_samples_leaf': [2],    
    'max_features': ['sqrt'], 
    'bootstrap': [True]         
}

#Entrenamos para cada objetivo
rf_base_grupo = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_grupo = GridSearchCV(rf_base_grupo, param_grid_rf_final_grupo_pool, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_grupo.fit(X_train_model, y_train_grupo)

rf_base_caja = RandomForestClassifier(class_weight='balanced', random_state=42)
grid_rf_caja = GridSearchCV(rf_base_caja, param_grid_rf_final_caja_pool, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_rf_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_rf_grupo, grid_rf_caja, "Random Forest - Pool")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# Mejores Hiperparámetros para Torácica: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# GRUPOS -> Accuracy: 54.66% | F1-Score (Macro): 20.56%
# CAJA TORÁCICA -> Accuracy: 52.23% | F1-Score (Macro): 35.52%

# %% [markdown]
# ##### SVM

# %%
param_grid_svm = {
    'C': [1.0],
    'kernel': ['rbf'],
    'gamma': ['scale']
}

svm_base_grupo = SVC(class_weight='balanced', random_state=42)
grid_svm_grupo = GridSearchCV(svm_base_grupo, param_grid_svm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_grupo.fit(X_train_model, y_train_grupo)

svm_base_caja = SVC(class_weight='balanced', random_state=42)
grid_svm_caja = GridSearchCV(svm_base_caja, param_grid_svm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_svm_grupo, grid_svm_caja, "SVM - Pool - Aumentado")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# Mejores Hiperparámetros para Torácica: {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# GRUPOS -> Accuracy: 29.15% | F1-Score (Macro): 21.70%
# CAJA TORÁCICA -> Accuracy: 23.48% | F1-Score (Macro): 16.72%

# %%
param_grid_svm_1 = {
    'C': [0.5, 1.0, 1.5],
    'kernel': ['rbf'],
    'gamma': ['scale']
}

svm_base_grupo = SVC(class_weight='balanced', random_state=42)
grid_svm_grupo = GridSearchCV(svm_base_grupo, param_grid_svm_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_grupo.fit(X_train_model, y_train_grupo)

svm_base_caja = SVC(class_weight='balanced', random_state=42)
grid_svm_caja = GridSearchCV(svm_base_caja, param_grid_svm_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_svm_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_svm_grupo, grid_svm_caja, "SVM - Pool")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'C': 1.5, 'gamma': 'scale', 'kernel': 'rbf'}
# Mejores Hiperparámetros para Torácica: {'C': 1.5, 'gamma': 'scale', 'kernel': 'rbf'}
# GRUPOS -> Accuracy: 28.34% | F1-Score (Macro): 19.37%
# CAJA TORÁCICA -> Accuracy: 24.70% | F1-Score (Macro): 16.95%

# %% [markdown]
# Rendimiento malo con svm, pasamos directamente a LGBM

# %% [markdown]
# ##### LightGBM

# %%
param_grid_lgbm = {
    'n_estimators': [100],
    'learning_rate': [0.1],
    'num_leaves': [31],
    'max_depth': [-1],
    'min_child_samples': [20]
}

lgbm_base_grupo = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_grupo = GridSearchCV(lgbm_base_grupo, param_grid_lgbm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_grupo.fit(X_train_model, y_train_grupo)

lgbm_base_caja = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_caja = GridSearchCV(lgbm_base_caja, param_grid_lgbm, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_lgbm_grupo, grid_lgbm_caja, "LightGBM - Pool - Aumentado")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 31}
# Mejores Hiperparámetros para Torácica: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 31}
# GRUPOS -> Accuracy: 57.89% | F1-Score (Macro): 23.89%
# CAJA TORÁCICA -> Accuracy: 55.06% | F1-Score (Macro): 37.78%

# %%
param_grid_lgbm_1 = {
    'n_estimators': [100, 200],
    'learning_rate': [0.05, 0.1],
    'num_leaves': [31, 63],
    'max_depth': [-1, 10],
    'min_child_samples': [20, 50]
}

lgbm_base_grupo = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_grupo = GridSearchCV(lgbm_base_grupo, param_grid_lgbm_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_grupo.fit(X_train_model, y_train_grupo)

lgbm_base_caja = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_caja = GridSearchCV(lgbm_base_caja, param_grid_lgbm_1, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_lgbm_grupo, grid_lgbm_caja, "LightGBM - Pool")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'learning_rate': 0.05, 'max_depth': 10, 'min_child_samples': 50, 'n_estimators': 100, 'num_leaves': 63}
# Mejores Hiperparámetros para Torácica: {'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 50, 'n_estimators': 100, 'num_leaves': 31}
# GRUPOS -> Accuracy: 53.04% | F1-Score (Macro): 22.32%
# CAJA TORÁCICA -> Accuracy: 51.82% | F1-Score (Macro): 26.89%

# %%
param_grid_lgbm_2 = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.1, 0.15],
    'num_leaves': [31, 63],
    'max_depth': [-1],
    'min_child_samples': [20]
}

lgbm_base_grupo = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_grupo = GridSearchCV(lgbm_base_grupo, param_grid_lgbm_2, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_grupo.fit(X_train_model, y_train_grupo)

lgbm_base_caja = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_caja = GridSearchCV(lgbm_base_caja, param_grid_lgbm_2, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_lgbm_grupo, grid_lgbm_caja, "LightGBM - Pool")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'learning_rate': 0.15, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 300, 'num_leaves': 31}
# Mejores Hiperparámetros para Torácica: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 63}
# GRUPOS -> Accuracy: 53.04% | F1-Score (Macro): 21.53%
# CAJA TORÁCICA -> Accuracy: 55.06% | F1-Score (Macro): 37.59%

# %%
param_grid_lgbm_final_grupo_pool = {
    'n_estimators': [100],
    'learning_rate': [0.1],
    'num_leaves': [31],
    'max_depth': [-1],
    'min_child_samples': [20]
}

param_grid_lgbm_final_caja_pool = {
    'n_estimators': [100],
    'learning_rate': [0.1],
    'num_leaves': [31],
    'max_depth': [-1],
    'min_child_samples': [20]
}

lgbm_base_grupo = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_grupo = GridSearchCV(lgbm_base_grupo, param_grid_lgbm_final_grupo_pool, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_grupo.fit(X_train_model, y_train_grupo)

lgbm_base_caja = LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=1, verbose=-1)
grid_lgbm_caja = GridSearchCV(lgbm_base_caja, param_grid_lgbm_final_caja_pool, scoring='f1_macro', cv=ps, n_jobs=-1)
grid_lgbm_caja.fit(X_train_model, y_train_caja)

evaluar_modelo_pool(grid_lgbm_grupo, grid_lgbm_caja, "LightGBM - Pool")
# Out:
# Mejores Hiperparámetros para Grupo Clínico: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 31}
# Mejores Hiperparámetros para Torácica: {'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 100, 'num_leaves': 31}
# GRUPOS -> Accuracy: 57.89% | F1-Score (Macro): 23.89%
# CAJA TORÁCICA -> Accuracy: 55.06% | F1-Score (Macro): 37.78%
